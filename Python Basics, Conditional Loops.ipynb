# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def solution1():
  for i in range(2000,3201):
    if (i%7==0 and i % 5==0):
      print(i,end=",")

# %%
solution1()
# Out:
# 2030,2065,2100,2135,2170,2205,2240,2275,2310,2345,2380,2415,2450,2485,2520,2555,2590,2625,2660,2695,2730,2765,2800,2835,2870,2905,2940,2975,3010,3045,3080,3115,3150,3185,

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def solution2():
  fname = input()
  lname = input()
  revfullname = fname[::-1] +' '+ lname[::-1]
  return revfullname

# %%
solution2()
# Out:
# rankush
# vishwakarma
# 'hsuknar amrakawhsiv'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from math import pi 
def solution3():
  return (4/3) * pi * (12**3)

# %%
solution3()
# Out:
# 7238.229473870882
