# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# first triangle
for i in range(5):
  for j in range(0,i+1):
    print("*",end="")
  print()
# second triangle
for i in range(5, 0, -1):  
  for j in range(0, i - 1):  
    print("*", end="")  
  print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def solution2():
  Inp_word = input()
  return Inp_word[::-1]

# %%
solution2()
# Out:
# ineuron
# 'norueni'
